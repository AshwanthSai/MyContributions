# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
import pandas as pd
#Data from 2013 - 2021 inclusive

data = {'Percentage of households in the United States owning one or more firearms': [37,42,41,39,42,43,37,42,42],
        'Income Disparity': [0.48,0.48,0.48,0.48,0.49,0.49,0.48,0.49,0.49],
        'Population in Poverty' : [313395,316168,318868,320372,323156,324356,325268,328059,328722],
        'Firearm Thefts' : [143040760,130560471,143628212,142055543,138964011,118382000,99585000,87716000,120382000],
        'Gun Violence Incidents' : [33760,39514,48128,54699,58109,54142,39596,43705,45079]
        }
df = pd.DataFrame(data)
print(df)
# Out:
#    Percentage of households in the United States owning one or more firearms  \
# 0                                                 37
# 1                                                 42
# 2                                                 41
# 3                                                 39
# 4                                                 42
# 5                                                 43
# 6                                                 37
# 7                                                 42
# 8                                                 42
#
#    Income Disparity  Population in Poverty  Firearm Thefts  \
# 0              0.48                 313395       143040760
# 1              0.48                 316168       130560471
# 2              0.48                 318868       143628212
# 3              0.48                 320372       142055543
# 4              0.49                 323156       138964011
# ...

# %%
df.corr()
corr_matrix = df.corr()

# %%
sn.heatmap(corr_matrix, annot=True)
plt.show()
